# %% [markdown]
# <a href="https://colab.research.google.com/github/kesireddysiva/Sivanarayana_INFO_5737_Spring_2024/blob/main/Sivanarayana_Reddy_Kesireddy_INFO5731_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 In-class Exercise 2**
#
# The purpose of this exercise is to understand users' information needs, and then collect data from different sources for analysis by implementing web scraping using Python.
#
# **Expectations**:
# *   Students are expected to complete the exercise during lecture period to meet the active participation criteria of the course.
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# **Total points**: 40
#
# **Deadline**: This in-class exercise is due at the end of the day tomorrow, at 11:59 PM.
#
# **Late submissions will have a penalty of 10% of the marks for each day of late submission. , and no requests will be answered. Manage your time accordingly.**

# %% [markdown]
# ## Question 1 (10 Points)
# Describe an interesting research question (or practical question or something innovative) you have in mind, what kind of data should be collected to answer the question(s)? Specify the amount of data needed for analysis. Provide detailed steps for collecting and saving the data.

# %% [markdown]
# **Research Question:** I aim to explore how the levels of particulate matter (PM2.5) pollution in major US cities evolved on a monthly and seasonal basis from 2022 to 2023. Is there evidence in the data indicating an improvement in air quality over the past year?
#
# **Data Collection:**
#
# 1. I will retrieve hourly PM2.5 readings from January 2022 to December 2023 for at least 10 major US cities, such as New York, Los Angeles, Chicago, Houston, Philadelphia, etc., totaling around 175,200 data points, using the OpenAQ API.
# 2. I will handle any missing data appropriately.
# 3. The hourly data will be aggregated to calculate monthly and annual averages for PM2.5 in each city.
# 4. Nationwide PM2.5 averages will also be computed.
# 5. The aggregated data will be saved in CSV format.
#
# **Data Analysis:**
#
# 1. I will compare monthly and seasonal PM2.5 trends across all 10 cities for the years 2022 and 2023.
# 2. The relative change in PM2.5 levels in each city between 2022 and 2023 will be calculated.
# 3. Visualizations will be created to illustrate the progression of PM2.5 levels, highlighting any noticeable monthly or seasonal pattern shifts.
# 4. I will explore potential correlations between PM2.5 levels and policy interventions or significant events.
# 5. Finally, conclusions will be drawn regarding how PM2.5 trends have evolved from 2022 to 2023 and what insights this provides about the effectiveness of air quality management efforts in the US.

# %% [markdown]
# ## Question 2 (10 Points)
# Write Python code to collect a dataset of 1000 samples related to the question discussed in Question 1.

# %%
# write your answer here
import requests
import pandas as pd
url = "https://api.openaq.org/v2/measurements?date_from=2022-01-01T00%3A00%3A00Z&date_to=2023-12-31T13%3A53%3A00Z&limit=2000&page=1&offset=0&sort=desc&radius=1000&order_by=datetime"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers)

# Extract JSON
data = response.json()['results']

# Transform to dataframe
df = pd.DataFrame(data)
df
# Out:
#       locationId            location parameter  value  \
# 0             21  Beijing US Embassy      pm25   25.0
# 1             21  Beijing US Embassy      pm25   27.0
# 2             21  Beijing US Embassy      pm25   22.0
# 3             21  Beijing US Embassy      pm25   29.0
# 4             21  Beijing US Embassy      pm25   23.0
# ...          ...                 ...       ...    ...
# 1995          21  Beijing US Embassy      pm25   38.0
# 1996          21  Beijing US Embassy      pm25   25.0
# 1997          21  Beijing US Embassy      pm25   16.0
# 1998          21  Beijing US Embassy      pm25   11.0
# 1999          21  Beijing US Embassy      pm25   11.0
#
#                                                    date   unit  \
# 0     {'utc': '2023-08-15T15:00:00+00:00', 'local': ...  µg/m³
# 1     {'utc': '2023-08-15T14:00:00+00:00', 'local': ...  µg/m³
# 2     {'utc': '2023-08-15T13:00:00+00:00', 'local': ...  µg/m³
# ...

# %% [markdown]
# ## Question 3 (10 Points)
# Write Python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "XYZ". The articles should be published in the last 10 years (2014-2024).
#
# The following information from the article needs to be collected:
#
# (1) Title of the article
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def fetch_google_scholar_articles(keyword, num_articles):
    articles = []
    base = 0

    while len(articles) < num_articles:
        url = f"https://scholar.google.com/scholar?q={keyword}&start={base}&as_ylo=2014&as_yhi=2024&hl=en&as_sdt=0%2C5"

        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        for result in soup.find_all('div', class_='gs_ri'):
            title = result.find('h3', class_='gs_rt').text.strip()
            venue = result.find('div', class_='gs_a').text.split('-')[0].strip()
            year = result.find('div', class_='gs_a').text.split(',')[-1].strip()
            authors = result.find('div', class_='gs_a').text.split('-')[1].strip()
            abstract = result.find('div', class_='gs_rs').text.strip()

            articles.append({
                'title': title,
                'venue': venue,
                'year': year,
                'authors': authors,
                'abstract': abstract
            })

            if len(articles) >= num_articles:
                break

        base += 10

    return articles[:num_articles]

keyword = "python"
num_articles = 100  # specifying the articles limit
articles_data = fetch_google_scholar_articles(keyword, num_articles) # calling the function

# Convert the list of articles to a DataFrame
df = pd.DataFrame(articles_data)

# Display the DataFrame
df
# Out:
#                                                 title  \
# 0                                   [PDF][PDF] Python
# 1                   [BOOK][B] Python machine learning
# 2                             [BOOK][B] Fluent python
# 3                   [BOOK][B] Python machine learning
# 4                      [BOOK][B] Python in a Nutshell
# ..                                                ...
# 95  [BOOK][B] Statistics, data mining, and machine...
# 96      [BOOK][B] Python: Real world machine learning
# 97  [BOOK][B] Natural Language Processing in Actio...
# 98  [PDF][PDF] librosa: Audio and music signal ana...
# 99    Applied natural language processing with python
#
#                                                 venue  \
# 0                                            W Python
# 1                                           S Raschka
# 2                                           L Ramalho
# 3                                              WM Lee
# ...

# %% [markdown]
# ## Question 4A (10 Points)
# Develop Python code to collect data from social media platforms like Reddit, Instagram, Twitter (formerly known as X), Facebook, or any other. Use hashtags, keywords, usernames, or user IDs to gather the data.
#
#
#
# Ensure that the collected data has more than four columns.

# %%
import os
from googleapiclient.discovery import build

# Replace 'YOUR_API_KEY' with your actual API key
API_KEY = 'AIzaSyAEDjBwxWK2IM7Hs_BmeFcfzneY-VjuopU'

# Set up the YouTube Data API service
youtube = build('youtube', 'v3', developerKey=API_KEY)

def search_videos(query, max_results=10):
    try:
        # Request video search results from YouTube API
        request = youtube.search().list(
            part='snippet',
            q=query,
            type='video',
            maxResults=max_results
        )
        response = request.execute()

        # Extract relevant information from the search results
        for item in response['items']:
            snippet = item['snippet']
            video_id = item['id']['videoId']

            # Print or process the information as needed
            print(f"Video Title: {snippet['title']}")
            print(f"Channel Title: {snippet['channelTitle']}")
            print(f"Publish Date: {snippet['publishedAt']}")
            print(f"Video ID: {video_id}")
            print(f"Thumbnail URL: {snippet['thumbnails']['default']['url']}")
            print("\n")

    except Exception as e:
        print(f"An error occurred: {e}")

# Replace 'YOUR_QUERY' with the actual search query you want to perform
search_query = 'ind vs eng'
search_videos(search_query)
# Out:
# Video Title: Live: IND Vs ENG, 3rd Test Day 2 | Live Scores &amp; Commentary | India Vs England | 2024 Series
# Channel Title: CricTalks
# Publish Date: 2024-02-16T02:25:33Z
# Video ID: qtISJ43gl1A
# Thumbnail URL: https://i.ytimg.com/vi/qtISJ43gl1A/default_live.jpg
#
#
# Video Title: LIVE: India v England 3rd Test, Day 2, Rajkot | talkSPORT Cricket
# Channel Title: talkSPORT Cricket
# Publish Date: 2024-02-16T04:12:08Z
# Video ID: OaAe37zdTME
# Thumbnail URL: https://i.ytimg.com/vi/OaAe37zdTME/default_live.jpg
#
#
# Video Title: India vs England, 3rd Test, Day 2 | India vs England Live Match | IND vs ENG Live Score &amp; Commentary
# Channel Title: Iqbal Sports
# Publish Date: 2024-02-15T15:00:52Z
# Video ID: uoma6TPFMgA
# Thumbnail URL: https://i.ytimg.com/vi/uoma6TPFMgA/default_live.jpg
#
#
# Video Title: Live: IND Vs ENG, 3rd Test Day 2 | Live Scores &amp; Commentary | India Vs England | Session 1
# Channel Title: CricTalks
# Publish Date: 2024-02-16T02:47:38Z
# ...

# %% [markdown]
# ## Question 4B (10 Points)
# If you encounter challenges with Question-4 web scraping using Python, employ any online tools such as ParseHub or Octoparse for data extraction. Introduce the selected tool, outline the steps for web scraping, and showcase the final output in formats like CSV or Excel.
#
#
#
# Upload a document (Word or PDF File) in any shared storage (preferably UNT OneDrive) and add the publicly accessible link in the below code cell.
#
# Please only choose one option for question 4. If you do both options, we will grade only the first one

# %%
# write your answer here

# %% [markdown]
# # Mandatory Question

# %% [markdown]
# **Important: Reflective Feedback on Web Scraping and Data Collection**
#
#
#
# Please share your thoughts and feedback on the web scraping and data collection exercises you have completed in this assignment. Consider the following points in your response:
#
#
#
# Learning Experience: Describe your overall learning experience in working on web scraping tasks. What were the key concepts or techniques you found most beneficial in understanding the process of extracting data from various online sources?
#
#
#
# Challenges Encountered: Were there specific difficulties in collecting data from certain websites, and how did you overcome them? If you opted for the non-coding option, share your experience with the chosen tool.
#
#
#
# Relevance to Your Field of Study: How might the ability to gather and analyze data from online sources enhance your work or research?
#
# **(no grading of your submission if this question is left unanswered)**

# %% [markdown]
# Working on web scraping tasks can be a valuable learning experience. Key concepts include understanding HTML structure, using libraries like BeautifulSoup for parsing, and making HTTP requests with tools like `requests`. While extracting the 1000 articles, I encountered timeout errors, or it took too much time to execute.
